# %%
import numpy as np
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Retrieving data

# %%
columns_name=["user_id","item_id","rating","timestamp"]

df=pd.read_csv("ml-100k/u.data",sep='\t',names=columns_name)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0      196      242       3  881250949
# 1      186      302       3  891717742
# 2       22      377       1  878887116
# 3      244       51       2  880606923
# 4      166      346       1  886397596

# %%
df.shape
# Out:
# (100000, 4)

# %%
df['user_id'].nunique()
# Out:
# 943

# %%
df['item_id'].nunique()
# Out:
# 1682

# %%
movies_title = pd.read_csv("ml-100k/u.item",sep='\|',header=None)

# %%
movies_title.shape
# Out:
# (1682, 24)

# %%
movies_title=movies_title[[0,1]]

# %%
movies_title.columns=['item_id','title']

movies_title.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df= pd.merge(df,movies_title,on='item_id')

# %% [markdown]
# # Exploring Data

# %%
import matplotlib.pyplot as plt
# !python -m pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\python\lib\site-packages (0.11.1)
# Requirement already satisfied: numpy>=1.15 in c:\python\lib\site-packages (from seaborn) (1.21.0)
# Requirement already satisfied: scipy>=1.0 in c:\python\lib\site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\python\lib\site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: pandas>=0.23 in c:\python\lib\site-packages (from seaborn) (1.2.5)
# Requirement already satisfied: cycler>=0.10 in c:\python\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\python\lib\site-packages (from matplotlib>=2.2->seaborn) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied: six in c:\users\esshaan\appdata\roaming\python\python39\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\python\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)

# %%
import seaborn as sns

# %%
sns.set_style('white')

# %%
df.groupby('title').mean()['rating'].sort_values(ascending=False).head()
# Out:
# title
# They Made Me a Criminal (1939)                5.0
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Saint of Fort Washington, The (1993)          5.0
# Someone Else's America (1995)                 5.0
# Star Kid (1997)                               5.0
# Name: rating, dtype: float64

# %%
df.groupby('title').count()['rating'].sort_values(ascending=False)
# Out:
# title
# Star Wars (1977)                      583
# Contact (1997)                        509
# Fargo (1996)                          508
# Return of the Jedi (1983)             507
# Liar Liar (1997)                      485
#                                      ...
# Great Day in Harlem, A (1994)           1
# Other Voices, Other Rooms (1997)        1
# Good Morning (1971)                     1
# Girls Town (1996)                       1
# � k�ldum klaka (Cold Fever) (1994)      1
# Name: rating, Length: 1664, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title').mean()['rating'])

# %%
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['Number of ratings'] = pd.DataFrame(df.groupby('title').count()['rating'])

# %%
ratings
# Out:
#                                          rating  Number of ratings
# title
# 'Til There Was You (1997)              2.333333                  9
# 1-900 (1994)                           2.600000                  5
# 101 Dalmatians (1996)                  2.908257                109
# 12 Angry Men (1957)                    4.344000                125
# 187 (1997)                             3.024390                 41
# ...                                         ...                ...
# Young Guns II (1990)                   2.772727                 44
# Young Poisoner's Handbook, The (1995)  3.341463                 41
# Zeus and Roxanne (1997)                2.166667                  6
# unknown                                3.444444                  9
# � k�ldum klaka (Cold Fever) (1994)     3.000000                  1
#
# [1664 rows x 2 columns]

# %%
ratings.sort_values(by='rating',ascending=False)
# Out:
#                                               rating  Number of ratings
# title
# They Made Me a Criminal (1939)                   5.0                  1
# Marlene Dietrich: Shadow and Light (1996)        5.0                  1
# Saint of Fort Washington, The (1993)             5.0                  2
# Someone Else's America (1995)                    5.0                  1
# Star Kid (1997)                                  5.0                  3
# ...                                              ...                ...
# Eye of Vichy, The (Oeil de Vichy, L') (1993)     1.0                  1
# King of New York (1990)                          1.0                  1
# Touki Bouki (Journey of the Hyena) (1973)        1.0                  1
# Bloody Child, The (1996)                         1.0                  1
# Crude Oasis, The (1995)                          1.0                  1
#
# [1664 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
plt.hist(ratings['Number of ratings'],bins=70)
plt.show()

# %%
plt.hist(ratings['rating'],bins=70)
plt.show()

# %%
sns.jointplot(x='rating',y='Number of ratings',data=ratings,alpha=0.5)

# %% [markdown]
# # Creating Movie Recommendation

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp         title
# 0      196      242       3  881250949  Kolya (1996)
# 1       63      242       3  875747190  Kolya (1996)
# 2      226      242       5  883888671  Kolya (1996)
# 3      154      242       3  879138235  Kolya (1996)
# 4      306      242       5  876503793  Kolya (1996)

# %%
moviemat = df.pivot_table(index='user_id',columns='title',values='rating')

# %%
moviemat
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
# ...                      ...         ...                          ...
# 939                      NaN         NaN                          NaN
# 940                      NaN         NaN                          NaN
# 941                      NaN         NaN                          NaN
# 942                      NaN         NaN                          NaN
# 943                      NaN         NaN                          2.0
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 1                                        3.0                           4.0
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# 5                                        NaN                           4.0
# ...                                      ...                           ...
# 939                                      NaN                           NaN
# 940                                      NaN                           NaN
# 941                                      NaN                           NaN
# 942                                      NaN                           3.0
# 943                                      NaN                           NaN
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 1                                                NaN                   NaN
# 2                                                1.0                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# 5                                                NaN                   NaN
# ...                                              ...                   ...
# 939                                              NaN                   NaN
# 940                                              NaN                   NaN
# 941                                              NaN                   NaN
# 942                                              NaN                   3.0
# 943                                              NaN                   NaN
#
# title    ...  Yankee Zulu (1994)  Year of the Horse (1997)  \
# user_id  ...
# 1        ...                 NaN                       NaN
# 2        ...                 NaN                       NaN
# 3        ...                 NaN                       NaN
# 4        ...                 NaN                       NaN
# 5        ...                 NaN                       NaN
# ...      ...                 ...                       ...
# 939      ...                 NaN                       NaN
# 940      ...                 NaN                       NaN
# 941      ...                 NaN                       NaN
# 942      ...                 NaN                       NaN
# 943      ...                 NaN                       NaN
#
# title    You So Crazy (1994)  Young Frankenstein (1974)  Young Guns (1988)  \
# user_id
# 1                        NaN                        5.0                3.0
# 2                        NaN                        NaN                NaN
# 3                        NaN                        NaN                NaN
# 4                        NaN                        NaN                NaN
# 5                        NaN                        4.0                NaN
# ...                      ...                        ...                ...
# 939                      NaN                        NaN                NaN
# 940                      NaN                        NaN                NaN
# 941                      NaN                        NaN                NaN
# 942                      NaN                        NaN                NaN
# 943                      NaN                        NaN                4.0
#
# title    Young Guns II (1990)  Young Poisoner's Handbook, The (1995)  \
# user_id
# 1                         NaN                                    NaN
# 2                         NaN                                    NaN
# 3                         NaN                                    NaN
# 4                         NaN                                    NaN
# 5                         NaN                                    NaN
# ...                       ...                                    ...
# 939                       NaN                                    NaN
# 940                       NaN                                    NaN
# 941                       NaN                                    NaN
# 942                       NaN                                    NaN
# 943                       3.0                                    NaN
#
# title    Zeus and Roxanne (1997)  unknown  � k�ldum klaka (Cold Fever) (1994)
# user_id
# 1                            NaN      4.0                                 NaN
# 2                            NaN      NaN                                 NaN
# 3                            NaN      NaN                                 NaN
# 4                            NaN      NaN                                 NaN
# 5                            NaN      4.0                                 NaN
# ...                          ...      ...                                 ...
# 939                          NaN      NaN                                 NaN
# 940                          NaN      NaN                                 NaN
# 941                          NaN      NaN                                 NaN
# 942                          NaN      NaN                                 NaN
# 943                          NaN      NaN                                 NaN
#
# [943 rows x 1664 columns]

# %%
ratings.sort_values('Number of ratings',ascending=False).head()
# Out:
#                              rating  Number of ratings
# title
# Star Wars (1977)           4.358491                583
# Contact (1997)             3.803536                509
# Fargo (1996)               4.155512                508
# Return of the Jedi (1983)  4.007890                507
# Liar Liar (1997)           3.156701                485

# %%
star_wars_rating = moviemat['Star Wars (1977)']

# %%
star_wars_rating.head()
# Out:
# user_id
# 1    5.0
# 2    5.0
# 3    NaN
# 4    5.0
# 5    4.0
# Name: Star Wars (1977), dtype: float64

# %%
similar_star_wars = moviemat.corrwith(star_wars_rating)

# %%
corr_starwars = pd.DataFrame(similar_star_wars,columns=['Correlation'])

# %%
corr_starwars.dropna(inplace=True)

# %%
corr_starwars
# Out:
#                                        Correlation
# title
# 'Til There Was You (1997)                 0.872872
# 1-900 (1994)                             -0.645497
# 101 Dalmatians (1996)                     0.211132
# 12 Angry Men (1957)                       0.184289
# 187 (1997)                                0.027398
# ...                                            ...
# Young Guns (1988)                         0.186377
# Young Guns II (1990)                      0.228615
# Young Poisoner's Handbook, The (1995)    -0.007374
# Zeus and Roxanne (1997)                   0.818182
# unknown                                   0.723123
#
# [1410 rows x 1 columns]

# %%
corr_starwars.sort_values("Correlation",ascending=False).head(n=10)
# Out:
#                                                     Correlation
# title
# Hollow Reed (1996)                                          1.0
# Commandments (1997)                                         1.0
# Cosi (1996)                                                 1.0
# No Escape (1994)                                            1.0
# Stripes (1981)                                              1.0
# Star Wars (1977)                                            1.0
# Man of the Year (1995)                                      1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0

# %%
corr_starwars =  corr_starwars.join(ratings['Number of ratings'])

# %%
corr_starwars
# Out:
#                                        Correlation  Number of ratings
# title
# 'Til There Was You (1997)                 0.872872                  9
# 1-900 (1994)                             -0.645497                  5
# 101 Dalmatians (1996)                     0.211132                109
# 12 Angry Men (1957)                       0.184289                125
# 187 (1997)                                0.027398                 41
# ...                                            ...                ...
# Young Guns (1988)                         0.186377                101
# Young Guns II (1990)                      0.228615                 44
# Young Poisoner's Handbook, The (1995)    -0.007374                 41
# Zeus and Roxanne (1997)                   0.818182                  6
# unknown                                   0.723123                  9
#
# [1410 rows x 2 columns]

# %%
corr_starwars[corr_starwars['Number of ratings']>100].sort_values(by='Correlation',ascending=False)
# Out:
#                                                     Correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.747981
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
# ...                                                         ...
# Edge, The (1997)                                      -0.127167
# As Good As It Gets (1997)                             -0.130466
# Crash (1996)                                          -0.148507
# G.I. Jane (1997)                                      -0.176734
# First Wives Club, The (1996)                          -0.194496
#
#                                                     Number of ratings
# title
# Star Wars (1977)                                                  583
# Empire Strikes Back, The (1980)                                   367
# Return of the Jedi (1983)                                         507
# Raiders of the Lost Ark (1981)                                    420
# Austin Powers: International Man of Mystery (1997)                130
# ...                                                               ...
# Edge, The (1997)                                                  113
# As Good As It Gets (1997)                                         112
# Crash (1996)                                                      128
# G.I. Jane (1997)                                                  175
# First Wives Club, The (1996)                                      160
#
# [334 rows x 2 columns]

# %% [markdown]
# ## Prediting function

# %%
def predict_movies(movie_name):
    movie_rating = moviemat[movie_name]
    similar_movie = moviemat.corrwith(movie_rating)
    
    corr_movie = pd.DataFrame(similar_movie,columns=['Correlation'])
    corr_movie.dropna(inplace=True)
    
    corr_movie =  corr_movie.join(ratings['Number of ratings'])
    
    predictions = corr_movie[corr_movie['Number of ratings']>100].sort_values(by='Correlation',ascending=False)
    return predictions

# %%
predictions = predict_movies("Titanic (1997)")

# %%
predictions.head()
# Out:
#                               Correlation  Number of ratings
# title
# Titanic (1997)                   1.000000                350
# River Wild, The (1994)           0.497600                146
# Abyss, The (1989)                0.472103                151
# Bram Stoker's Dracula (1992)     0.443560                120
# True Lies (1994)                 0.435104                208
